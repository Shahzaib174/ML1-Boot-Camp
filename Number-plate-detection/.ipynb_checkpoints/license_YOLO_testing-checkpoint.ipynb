# %% [markdown]
# # **"Shirt Color Prediction Using YOLOv8"**

# %% [markdown]
# ### The purpose of this notebook is to test the YOLOv8 model for shirt color prediction.
#
# #### **Libraries Used:**
# >ultralytics
#
# >matplotlib.pyplot
#
# >cv2
#
# #### **What is ultralytics library?**
# >Ultralytics is a library for object detection, segmentation, and instance segmentation. It is used for image and video analysis.
#
# #### **How to use?**
#
# >1. Load the best weights of YOLOv8 model trained on the custom shirts data
#
# >2. Store the predictions of model
#
# >3. Using different scripts, test it on images, videos and live feed

# %% [markdown]
# # +_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+

# %% [markdown]
# ## **Install ultralytics**

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\majid\anaconda3\lib\site-packages (8.2.66)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (3.9.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\majid\anaconda3\lib\site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\majid\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\majid\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\majid\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\majid\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\majid\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\majid\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\majid\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\majid\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: colorama in c:\users\majid\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\majid\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\majid\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\majid\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %% [markdown]
# ## **Load the best weights of trained YOLO**

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

# %% [markdown]
# ## **Test model on image files**

# %%
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# Load the image
image_path = 'car_139.jpg'
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

# Make predictions
results = model.predict(source=image_path)

# Plot the image with predictions
fig, ax = plt.subplots(figsize=(4, 4))
ax.imshow(image)
ax.axis('off')  # Hide axes
ax.set_title('Predictions on Image')

# Plot the bounding boxes and labels
for result in results:
    boxes = result.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]
        ax.add_patch(plt.Rectangle((x1, y1), x2-x1, y2-y1, fill=False, edgecolor='green', linewidth=2))
        label = f"{result.names[int(box.cls[0])]}: {box.conf[0]:.2f}"
        ax.text(x1, y1, label, fontsize=6, color='white', bbox=dict(facecolor='green', edgecolor='green', alpha=0.6))

plt.show()
# Out:
# image 1/1 c:\Users\majid\Downloads\train8 (1)\car_139.jpg: 640x640 1 Number-Plate, 137.7ms
# Speed: 6.6ms preprocess, 137.7ms inference, 14.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
pip install easyocr
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting easyocr
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (2.4.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (0.19.0)
# Collecting opencv-python-headless (from easyocr)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.26.2)
# Requirement already satisfied: Pillow in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (10.1.0)
# Collecting scikit-image (from easyocr)
#   Using cached scikit_image-0.24.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: python-bidi in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (0.6.0)
# Requirement already satisfied: PyYAML in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (2.0.5)
# Requirement already satisfied: pyclipper in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (4.8.0)
# Requirement already satisfied: sympy in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from torch->easyocr) (2024.2.0)
# Collecting imageio>=2.33 (from scikit-image->easyocr)
#   Using cached imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (2024.7.24)
# Requirement already satisfied: packaging>=21 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->easyocr) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\majid\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached scikit_image-0.24.0-cp39-cp39-win_amd64.whl (12.9 MB)
# Using cached imageio-2.34.2-py3-none-any.whl (313 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Installing collected packages: opencv-python-headless, lazy-loader, imageio, scikit-image, easyocr
# Successfully installed easyocr-1.7.1 imageio-2.34.2 lazy-loader-0.4 opencv-python-headless-4.10.0.84 scikit-image-0.24.0

# %% [markdown]
# ## **Apply EasyOCR**

# %%
pip install opencv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement opencv (from versions: none)
# ERROR: No matching distribution found for opencv
#
# [notice] A new release of pip is available: 23.3.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# Initialize EasyOCR Reader
reader = easyocr.Reader(['en'])  # Specify the languages you want to use

# Load the image
image_path = 'car_139.jpg'
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

# Make predictions using the YOLOv8 model
results = model.predict(source=image_path)

# Store extracted license plate texts
extracted_texts = []

# Process each detection
for result in results:
    boxes = result.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates

        # Crop the license plate from the image
        license_plate = image_rgb[int(y1):int(y2), int(x1):int(x2)]

        # Apply OCR to the license plate image
        license_plate_text = reader.readtext(license_plate)

        # Extract the text and confidence from the OCR results
        if license_plate_text:
            # Initialize a list to hold the detected text lines
            text_lines = []
            for detection in license_plate_text:
                # Each detection contains (bounding box, text, confidence)
                bbox, text, confidence = detection
                # Store the extracted text and confidence
                extracted_texts.append((text, confidence))
                text_lines.append(text)  # Append the detected text line

            # Join all detected lines into a single string
            full_text = ' '.join(text_lines)

            # Draw the bounding box and license plate text on the image
            cv2.rectangle(image_rgb, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 0), 2)
            y = int(y1) - 10 if int(y1) - 10 > 10 else int(y1) + 10
            
            # Add background to the text
            (text_width, text_height), _ = cv2.getTextSize(f'License Plate: {full_text} (Conf: {confidence:.2f})', 
                                                           cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
            cv2.rectangle(image_rgb, (int(x1), y - text_height - 5), (int(x1 + text_width), y), 
                          (255, 255, 255), -1)
            
            # Draw the text with the background
            cv2.putText(image_rgb, f'License Plate: {full_text} (Conf: {confidence:.2f})', 
                        (int(x1), y), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.4, (0, 0, 0), 1)

# Display the image with OCR results using Matplotlib
plt.figure(figsize=(5, 5))
plt.imshow(image_rgb)
plt.axis('off')  # Hide axes
plt.title('License Plate Detection with EasyOCR')
plt.show()

# Print the extracted license plate texts in a single line
if extracted_texts:
    # Join the text parts from extracted_texts
    final_text = ' '.join(text for text, conf in extracted_texts)
    print(f'Extracted License Plate: {final_text}')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# image 1/1 c:\Users\majid\Downloads\train8 (1)\car_139.jpg: 640x640 1 Number-Plate, 85.0ms
# Speed: 5.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Extracted License Plate: MH.06.BE.7442

# %% [markdown]
# ## **SubPlot with EasyOCR**

# %%
import os
import cv2
import easyocr
import pandas as pd
import matplotlib.pyplot as plt

# Initialize EasyOCR Reader
reader = easyocr.Reader(['en'])  # Specify the languages you want to use

# Set the folder path containing the images
folder_path = r'C:\Users\majid\vechile\vechileclass\images\test'

# Create a list to store the extracted license plate texts
extracted_texts = []

# Get the list of image files in the folder
image_files = [filename for filename in os.listdir(folder_path) if filename.endswith(('.jpg', '.png', '.jpeg', '.webp'))]
num_images = len(image_files)

# Create a figure with subplots
num_rows = (num_images + 1) // 2  # Calculate number of rows needed
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 12))

# Iterate over the images in the folder
for i, filename in enumerate(image_files):
    # Load the image
    image_path = os.path.join(folder_path, filename)
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

    # Make predictions using the YOLOv8 model
    results = model.predict(source=image_path)

    # Initialize a list to hold the detected text lines
    text_lines = []

    # Process each detection
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates

            # Crop the license plate from the image
            license_plate = image_rgb[int(y1):int(y2), int(x1):int(x2)]

            # Apply OCR to the license plate image
            license_plate_text = reader.readtext(license_plate)

            # Extract the text and confidence from the OCR results
            if license_plate_text:
                for detection in license_plate_text:
                    # Each detection contains (bounding box, text, confidence)
                    bbox, text, confidence = detection
                    text_lines.append(text)  # Append the detected text line

    # Join all detected lines into a single string
    full_text = ' '.join(text_lines)

    # Store the extracted license plate text in the list
    extracted_texts.append((filename, full_text))

    # Draw the bounding box and license plate text on the image
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates
            cv2.rectangle(image_rgb, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 0), 2)
            y = int(y1) - 10 if int(y1) - 10 > 10 else int(y1) + 10
            
            # Add background to the text
            (text_width, text_height), _ = cv2.getTextSize(f'License Plate: {full_text}', 
                                                           cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
            cv2.rectangle(image_rgb, (int(x1), y - text_height - 5), (int(x1 + text_width), y), 
                          (255, 255, 255), -1)
            
            # Draw the text with the background
            cv2.putText(image_rgb, f'License Plate: {full_text}', 
                        (int(x1), y), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.4, (0, 0, 0), 1)

    # Display the image with OCR results in the subplot
    row = i // 2
    col = i % 2
    axes[row, col].imshow(image_rgb)
    axes[row, col].axis('off')
    axes[row, col].set_title(filename)

# Hide any unused subplots
for j in range(i + 1, num_rows * 2):
    axes[j // 2, j % 2].axis('off')

# Save the figure
plt.savefig('license_plate_detection.png')

# Create a DataFrame to store the extracted license plate texts
results_df = pd.DataFrame(extracted_texts, columns=['Filename', 'License Plate'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_13.jpg: 640x640 1 Number-Plate, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_14.jpg: 640x640 1 Number-Plate, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_15.jpg: 640x640 1 Number-Plate, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_16.jpg: 640x640 1 Number-Plate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_17.jpg: 640x640 1 Number-Plate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_18.jpg: 640x640 1 Number-Plate, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_19.jpg: 640x640 1 Number-Plate, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_20.jpg: 640x640 1 Number-Plate, 86.0ms
# Speed: 3.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_21.jpg: 640x640 1 Number-Plate, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\majid\vechile\vechileclass\images\test\car_22.jpg: 640x640 1 Number-Plate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
results_df
# Out:
#      Filename  License Plate
# 0  car_13.jpg   M4 43 222122
# 1  car_14.jpg   MH.43.X.3940
# 2  car_15.jpg     MOSAlvi450
# 3  car_16.jpg  Mh Z6 AP 9696
# 4  car_17.jpg      Ah3R 9362
# 5  car_18.jpg      AH47 4701
# 6  car_19.jpg    MHAG LJa 76
# 7  car_20.jpg  mh 43 AR 3892
# 8  car_21.jpg      KAZ7H7259
# 9  car_22.jpg  MH 02 DJ 5495

# %% [markdown]
# ## **Using Paddle OCR**

# %%
# !pip install paddlepaddle

# %%
# !pip install paddleocr

# %%
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR

# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Specify the language you want to use

# Set the folder path containing the images
folder_path = 'X:/ML1/WEEK5/day2/'

# Create a list to store the extracted license plate texts
extracted_texts = []

# Get the list of image files in the folder
image_files = [filename for filename in os.listdir(folder_path) if filename.endswith(('.jpg', '.png', '.jpeg', '.webp'))]
num_images = len(image_files)

# Create a figure with subplots
num_rows = (num_images + 1) // 2  # Calculate number of rows needed
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 12))

# Iterate over the images in the folder
for i, filename in enumerate(image_files):
    # Load the image
    image_path = os.path.join(folder_path, filename)
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

    # Make predictions using the YOLOv8 model
    results = model.predict(source=image_path)

    # Initialize a list to hold the detected text lines
    text_lines = []

    # Process each detection
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates

            # Crop the license plate from the image
            license_plate = image_rgb[int(y1):int(y2), int(x1):int(x2)]

            # Apply OCR to the license plate image using PaddleOCR
            ocr_results = ocr.ocr(license_plate, cls=True)

            # Extract the text and confidence from the OCR results
            if ocr_results:
                for line in ocr_results[0]:  # Each line contains (box, (text, confidence))
                    _, (text, confidence) = line
                    text_lines.append(text)  # Append the detected text line

    # Join all detected lines into a single string
    full_text = ' '.join(text_lines)

    # Store the extracted license plate text in the list
    extracted_texts.append((filename, full_text))

    # Draw the bounding box and license plate text on the image
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates
            cv2.rectangle(image_rgb, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 0), 2)
            y = int(y1) - 10 if int(y1) - 10 > 10 else int(y1) + 10
            
            # Add background to the text
            (text_width, text_height), _ = cv2.getTextSize(f'License Plate: {full_text}', 
                                                           cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
            cv2.rectangle(image_rgb, (int(x1), y - text_height - 5), (int(x1 + text_width), y), 
                          (255, 255, 255), -1)
            
            # Draw the text with the background
            cv2.putText(image_rgb, f'License Plate: {full_text}', 
                        (int(x1), y), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.4, (0, 0, 0), 1)

    # Display the image with OCR results in the subplot
    row = i // 2
    col = i % 2
    axes[row, col].imshow(image_rgb)
    axes[row, col].axis('off')
    axes[row, col].set_title(filename)

# Hide any unused subplots
for j in range(i + 1, num_rows * 2):
    axes[j // 2, j % 2].axis('off')

# Save the figure
plt.tight_layout()
plt.savefig('license_plate_detection_paddle.png')

# Create a DataFrame to store the extracted license plate texts
resultspaddle_df = pd.DataFrame(extracted_texts, columns=['Filename', 'License Plate'])
# Out:
# [2024/07/31 10:59:46] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\PMLS/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\PMLS/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='c:\\Users\\PMLS\\anaconda3\\envs\\traning_env\\lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\PMLS/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, ocr=True, recovery=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# image 1/1 X:\ML1\WEEK5\day2\Cars39_png.rf.fe511779e2f9eb9d412827d8d91f722b.jpg: 480x640 1 licence, 151.8ms
# Speed: 3.9ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [2024/07/31 10:59:48] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.018000125885009766
# [2024/07/31 10:59:48] ppocr DEBUG: cls num  : 1, elapsed : 0.019001007080078125
# [2024/07/31 10:59:48] ppocr DEBUG: rec_res num  : 1, elapsed : 0.15805530548095703
#
# image 1/1 X:\ML1\WEEK5\day2\Cars54_png.rf.cb6867c72116a0b5e843d70cbe18c480.jpg: 480x640 1 licence, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# [2024/07/31 10:59:48] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.13122248649597168
# [2024/07/31 10:59:48] ppocr DEBUG: cls num  : 1, elapsed : 0.0060002803802490234
# [2024/07/31 10:59:48] ppocr DEBUG: rec_res num  : 1, elapsed : 0.11294341087341309
#
# image 1/1 X:\ML1\WEEK5\day2\Cars82_png.rf.90607df58f8987cc60238b328b92d75b.jpg: 256x640 1 licence, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 640)
# [2024/07/31 10:59:48] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.11406946182250977
# [2024/07/31 10:59:48] ppocr DEBUG: cls num  : 1, elapsed : 0.009001493453979492
# [2024/07/31 10:59:48] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0879981517791748
#
# image 1/1 X:\ML1\WEEK5\day2\pk_isl.png: 384x640 1 licence, 68.0ms
# Speed: 1.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [2024/07/31 10:59:48] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.04659390449523926
# [2024/07/31 10:59:48] ppocr DEBUG: cls num  : 2, elapsed : 0.013000011444091797
# [2024/07/31 10:59:49] ppocr DEBUG: rec_res num  : 2, elapsed : 0.2620682716369629
#
# image 1/1 X:\ML1\WEEK5\day2\pk_l.png: 384x640 1 licence, 65.9ms
# Speed: 3.0ms preprocess, 65.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# [2024/07/31 10:59:49] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.031022310256958008
# [2024/07/31 10:59:49] ppocr DEBUG: cls num  : 3, elapsed : 0.01599717140197754
# [2024/07/31 10:59:49] ppocr DEBUG: rec_res num  : 3, elapsed : 0.22761988639831543

# %%
resultspaddle_df
# Out:
#                                             Filename         License Plate
# 0  Cars39_png.rf.fe511779e2f9eb9d412827d8d91f722b...            MH15BD8877
# 1  Cars54_png.rf.cb6867c72116a0b5e843d70cbe18c480...               LTM:378
# 2  Cars82_png.rf.90607df58f8987cc60238b328b92d75b...            UP16TC1366
# 3                                         pk_isl.png  AB-123 ICT- SLAMABAD
# 4                                           pk_l.png          LER -20 1234

# %% [markdown]
# ## **Test model on video files**

# %%
import cv2

# Load the video
video_path = 'traffic.mp4'
cap = cv2.VideoCapture(video_path)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Make predictions
    results = model.predict(source=frame)

    # Draw bounding boxes and labels on the frame
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates
            conf = box.conf[0]  # Get the confidence
            cls = box.cls[0]  # Get the class

            # Draw the bounding box and label
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, f'Class: {result.names[int(box.cls[0])]}, Conf: {conf:.2f}', (int(x1), int(y1) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the frame with predictions
    cv2.imshow('Video Predictions', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 licences, 215.7ms
# Speed: 10.9ms preprocess, 215.7ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 62.7ms
# Speed: 2.0ms preprocess, 62.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.3ms
# Speed: 2.0ms preprocess, 56.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 69.9ms
# Speed: 2.0ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.1ms
# Speed: 3.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.4ms
# Speed: 3.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 64.4ms
# Speed: 2.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 71.1ms
# Speed: 2.6ms preprocess, 71.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 76.1ms
# Speed: 2.0ms preprocess, 76.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 67.2ms
# Speed: 2.0ms preprocess, 67.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 114.8ms
# Speed: 4.0ms preprocess, 114.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.1ms
# Speed: 1.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 50.1ms
# Speed: 3.0ms preprocess, 50.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 55.1ms
# Speed: 2.0ms preprocess, 55.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 56.6ms
# Speed: 2.0ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 55.8ms
# Speed: 3.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 licences, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 55.9ms
# Speed: 2.0ms preprocess, 55.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 55.2ms
# Speed: 3.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 57.6ms
# Speed: 2.0ms preprocess, 57.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 55.2ms
# Speed: 2.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 60.2ms
# Speed: 2.0ms preprocess, 60.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 74.8ms
# Speed: 3.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 58.6ms
# Speed: 1.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 licence, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.9ms
# Speed: 1.5ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 57.2ms
# Speed: 2.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 licences, 53.3ms
# Speed: 2.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# !pip install sort-track
# Out:
# Requirement already satisfied: sort-track in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (0.0.8)
# Requirement already satisfied: filterpy==1.4.5 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from sort-track) (1.4.5)
# Requirement already satisfied: scipy==1.9.3 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from sort-track) (1.9.3)
# Requirement already satisfied: numpy in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from filterpy==1.4.5->sort-track) (1.25.2)
# Requirement already satisfied: matplotlib in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from filterpy==1.4.5->sort-track) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from matplotlib->filterpy==1.4.5->sort-track) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->filterpy==1.4.5->sort-track) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\pmls\anaconda3\envs\traning_env\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy==1.4.5->sort-track) (1.16.0)

# %%
import cv2
import pandas as pd
import numpy as np
from paddleocr import PaddleOCR
from sort import Sort

# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

# Set the path to the video file
video_path = 'X:/ML1/WEEK5/day2/traffic.mp4'  # Change this to your video file path

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the video's width, height, and frames per second (fps)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create a VideoWriter object to save the output video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_with_ocr.mp4', fourcc, fps, (width, height))

# Create a list to store the extracted license plate texts
extracted_texts = []

# Initialize SORT tracker
tracker = Sort()

# Dictionary to store the license plate text for each tracked object
tracked_plates = {}

# Process the video frame by frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for processing

    # Make predictions using the YOLOv8 model
    results = model.predict(source=image_rgb)

    # Prepare detections for the SORT tracker
    detections = []
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            score = box.confidence[0]
            detections.append([x1, y1, x2, y2, score])

    # Update tracker with detections
    tracked_objects = tracker.update(np.array(detections))

    # Process each tracked object
    for obj in tracked_objects:
        x1, y1, x2, y2, obj_id = obj
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

        # Crop the license plate from the image
        license_plate = image_rgb[y1:y2, x1:x2]

        # Apply OCR to the license plate image using PaddleOCR
        ocr_results = ocr.ocr(license_plate, cls=True)

        # Extract the text and confidence from the OCR results
        if ocr_results and ocr_results[0] is not None:
            for line in ocr_results[0]:  # Each line contains (box, (text, confidence))
                _, (text, confidence) = line
                if obj_id not in tracked_plates:  # Check if the plate is already detected
                    tracked_plates[obj_id] = text  # Add to the tracked plates

        # Get the license plate text for the current tracked object
        license_plate_text = tracked_plates.get(obj_id, "")

        # Draw the bounding box and license plate text on the image
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        y = y1 - 10 if y1 - 10 > 10 else y1 + 10

        # Add background to the text
        (text_width, text_height), _ = cv2.getTextSize(f'License Plate: {license_plate_text}', 
                                                       cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        cv2.rectangle(frame, (x1, y - text_height - 5), (x1 + text_width, y), (255, 255, 255), -1)
        
        # Draw the text with the background
        cv2.putText(frame, f'License Plate: {license_plate_text}', (x1, y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 0, 0), 1)

    # Write the frame into the file
    out.write(frame)

    # Display the processed frame
    cv2.imshow('Processed Video', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and writer objects
cap.release()
out.release()
cv2.destroyAllWindows()

# Create a DataFrame to store the extracted license plate texts
results_df = pd.DataFrame(extracted_texts, columns=['License Plate'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 import numpy as np
#       4 from paddleocr import PaddleOCR
# ----> 5 from sort import Sort
#       7 # Initialize PaddleOCR
#       8 ocr = PaddleOCR(use_angle_cls=True, lang='en')
#
# ImportError: cannot import name 'Sort' from 'sort' (c:\Users\PMLS\anaconda3\envs\traning_env\lib\site-packages\sort\__init__.py)

# %% [markdown]
# #### Video Results:

# %% [markdown]
# ## **Test model on live camera**

# %%
import cv2

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Make predictions
    results = model.predict(source=frame)

    # Draw bounding boxes and labels on the frame
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Get the bounding box coordinates
            conf = box.conf[0]  # Get the confidence
            cls = box.cls[0]  # Get the class

            # Draw the bounding box and label
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            cv2.putText(frame, f'Class: {result.names[int(box.cls[0])]}, Conf: {conf:.2f}', (int(x1), int(y1) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the frame with predictions
    cv2.imshow('Video Predictions', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 grey shirt, 133.4ms
# Speed: 7.0ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grey shirt, 99.4ms
# Speed: 2.0ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 119.1ms
# Speed: 2.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 81.1ms
# Speed: 2.2ms preprocess, 81.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.3ms
# Speed: 3.0ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.7ms
# Speed: 2.0ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.6ms
# Speed: 3.5ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grey shirt, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grey shirt, 78.3ms
# Speed: 2.0ms preprocess, 78.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grey shirt, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 2.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 123.3ms
# Speed: 1.0ms preprocess, 123.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.0ms
# Speed: 1.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.4ms
# Speed: 2.0ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.0ms
# Speed: 1.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 2.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.7ms
# Speed: 3.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.0ms
# Speed: 1.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.6ms
# Speed: 2.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 68.2ms
# Speed: 2.0ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 111.6ms
# Speed: 3.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 68.6ms
# Speed: 2.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 69.6ms
# Speed: 2.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.4ms
# Speed: 2.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 1 black shirt, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 1 black shirt, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 1 black shirt, 70.0ms
# Speed: 2.2ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 1 black shirt, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 1 black shirt, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.4ms
# Speed: 2.0ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt,
ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 102.8ms
# Speed: 4.0ms preprocess, 102.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 black shirt, 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 grey shirt, 89.7ms
# Speed: 3.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.2ms
# Speed: 3.0ms preprocess, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 114.6ms
# Speed: 4.0ms preprocess, 114.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.0ms
# Speed: 2.0ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 98.6ms
# Speed: 2.0ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 120.7ms
# Speed: 3.0ms preprocess, 120.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 123.5ms
# Speed: 3.5ms preprocess, 123.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 110.8ms
# Speed: 2.5ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 191.7ms
# Speed: 3.0ms preprocess, 191.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 blue shirt, 173.3ms
# Speed: 3.0ms preprocess, 173.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ## **Test model on multiple images**

# %%
import os
import glob
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# Folder containing the images
folder_path = 'X:/ML1/WEEK4/day4/'

# Supported image file extensions
image_extensions = ['*.jpg', '*.jpeg', '*.png', '*.webp']

# Get all image files in the folder
image_files = []
for ext in image_extensions:
    image_files.extend(glob.glob(os.path.join(folder_path, ext)))

# Determine the number of rows and columns for the subplot grid
num_images = len(image_files)
cols = 3  # Number of columns in the subplot grid
rows = (num_images + cols - 1) // cols  # Number of rows needed

# Create a figure for subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 5))
axes = axes.flatten()

# Process and plot each image
for idx, image_path in enumerate(image_files):
    # Load and convert the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Make predictions
    results = model.predict(source=image_path)

    # Plot the image with predictions
    ax = axes[idx]
    ax.imshow(image)
    ax.axis('off')  # Hide axes
    ax.set_title(os.path.basename(image_path))

    # Plot the bounding boxes and labels
    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            ax.add_patch(plt.Rectangle((x1, y1), x2-x1, y2-y1, fill=False, edgecolor='blue', linewidth=2))
            label = f"{result.names[int(box.cls[0])]}: {box.conf[0]:.2f}"
            ax.text(x1, y1, label, fontsize=12, color='white', bbox=dict(facecolor='blue', edgecolor='blue', alpha=0.8))

# Hide any unused subplots
for i in range(num_images, len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/1 X:\ML1\WEEK4\day4\26-1-600x600.jpg: 640x640 1 blue shirt, 188.9ms
# Speed: 11.0ms preprocess, 188.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 X:\ML1\WEEK4\day4\gr.jpg: 640x384 1 black shirt, 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 X:\ML1\WEEK4\day4\1_ef307dcc-7da9-4bad-be7d-52abd9face71.webp: 640x544 1 blue shirt, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 X:\ML1\WEEK4\day4\3_2.webp: 640x640 1 black shirt, 144.7ms
# Speed: 4.0ms preprocess, 144.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 X:\ML1\WEEK4\day4\48-assfmmopd44109-allen-solly-original-imagkc43caqruuzn.webp: 640x448 1 blue shirt, 160.4ms
# Speed: 5.1ms preprocess, 160.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)

# %%
# !python predict_modified.py model= 'X:/ML1/WEEK5/day2/runs_backup/detect/train2/weights/best.pt' source='traffic.mp4'
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\Users\PMLS\anaconda3\envs\traning_env\lib\site-packages\easyocr\detection.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(trained_model, map_location=device)))
# c:\Users\PMLS\anaconda3\envs\traning_env\lib\site-packages\easyocr\recognition.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path, map_location=device)
# LexerNoViableAltException: 'X:/ML1/WEEK5/day2/runs_backup/detect/train2/weights/best.pt'
#                            ^
# See https://hydra.cc/docs/1.2/advanced/override_grammar/basic for details
#
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
